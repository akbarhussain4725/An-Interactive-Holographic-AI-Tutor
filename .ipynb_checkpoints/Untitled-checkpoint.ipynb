# %%
import random

from tensorflow.keras.optimizers import SGD

from keras.layers import Dense, Dropout
from keras.models import load_model
from keras.models import Sequential
import numpy as np
import pickle
import json  
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('omw-1.4')
nltk.download("punkt")
nltk.download("wordnet")


words = []
classes = []
documents = []
ignore_words = ["?", "!"]
with open('final_dataset.json', encoding='utf-8') as file:
    data_file = file.read()
intents = json.loads(data_file)

for intent in intents["intents"]:
    for pattern in intent["patterns"]:

        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w, intent["tag"]))

        if intent["tag"] not in classes:
            classes.append(intent["tag"])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

#print(len(documents), "documents")

#print(len(classes), "classes", classes)

#print(len(words), "unique lemmatized words", words)


pickle.dump(words, open("words.pkl", "wb"))
pickle.dump(classes, open("classes.pkl", "wb"))

training = []
output_empty = [0] * len(classes)
for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])


    training.append([bag, output_row])
random.shuffle(training)
training = np.array(training,dtype=object)
train_x = list(training[:, 0])
train_y = list(training[:, 1])
print("Training data created")

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation="softmax"))
model.summary()

sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss="categorical_crossentropy", optimizer=sgd, metrics=["accuracy"])


hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5)
model.save("chatbot_model.h5", hist)
print("model created")
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\hussa\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hussa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hussa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Training data created
# C:\Users\hussa\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │          92,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 113)                 │           7,345 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 108,017 (421.94 KB)
#  Trainable params: 108,017 (421.94 KB)
#  Non-trainable params: 0 (0.00 B)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.0221 - loss: 4.6727
# Epoch 2/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.1470 - loss: 3.8744
# Epoch 3/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.3310 - loss: 2.6735
# Epoch 4/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.4539 - loss: 2.0202
# Epoch 5/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.5162 - loss: 1.7405
# Epoch 6/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.5892 - loss: 1.4620
# Epoch 7/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6049 - loss: 1.4143
# Epoch 8/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6430 - loss: 1.2718
# Epoch 9/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6624 - loss: 1.1932
# Epoch 10/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6722 - loss: 1.1950
# Epoch 11/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6647 - loss: 1.2089
# Epoch 12/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6785 - loss: 1.1781
# Epoch 13/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6874 - loss: 1.1398
# Epoch 14/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6989 - loss: 1.1375
# Epoch 15/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.7019 - loss: 1.1228
# Epoch 16/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6778 - loss: 1.2293
# Epoch 17/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6896 - loss: 1.1759
# Epoch 18/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6851 - loss: 1.2210
# Epoch 19/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6881 - loss: 1.2030
# Epoch 20/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7032 - loss: 1.1744
# Epoch 21/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6890 - loss: 1.2474
# Epoch 22/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6707 - loss: 1.3725
# Epoch 23/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6947 - loss: 1.2599
# Epoch 24/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6738 - loss: 1.3369
# Epoch 25/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6673 - loss: 1.4008
# Epoch 26/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6742 - loss: 1.4050
# Epoch 27/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.6807 - loss: 1.3783
# Epoch 28/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6798 - loss: 1.3571
# Epoch 29/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6765 - loss: 1.4064
# Epoch 30/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6680 - loss: 1.4732
# Epoch 31/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6525 - loss: 1.5726
# Epoch 32/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6628 - loss: 1.5074
# Epoch 33/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6489 - loss: 1.6112
# Epoch 34/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6546 - loss: 1.6149
# Epoch 35/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6493 - loss: 1.6186
# Epoch 36/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6532 - loss: 1.6442
# Epoch 37/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6327 - loss: 1.7091
# Epoch 38/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6516 - loss: 1.6259
# Epoch 39/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6556 - loss: 1.6098
# Epoch 40/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6338 - loss: 1.6930
# Epoch 41/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6499 - loss: 1.6877
# Epoch 42/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6473 - loss: 1.6945
# Epoch 43/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6255 - loss: 1.8355
# Epoch 44/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6227 - loss: 1.8645
# Epoch 45/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.6243 - loss: 1.9175
# Epoch 46/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.
200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4007 - loss: 2.7330
# Epoch 192/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3955 - loss: 2.7791
# Epoch 193/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3952 - loss: 2.7301
# Epoch 194/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4063 - loss: 2.6197
# Epoch 195/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4030 - loss: 2.6149
# Epoch 196/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4070 - loss: 2.6442
# Epoch 197/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4001 - loss: 2.6483
# Epoch 198/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.3995 - loss: 2.6377
# Epoch 199/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3903 - loss: 2.7131
# Epoch 200/200
# 1392/1392 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3955 - loss: 2.6668
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model created

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hussa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Predict on training data (you can also use a separate test set if available)
y_pred = model.predict(np.array(train_x))
y_pred_classes = np.argmax(y_pred, axis=1)

y_true = np.argmax(np.array(train_y), axis=1)

# Classification Report
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=classes))

# Confusion Matrix
print("\nConfusion Matrix:\n")
print(confusion_matrix(y_true, y_pred_classes))
# Out:
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Classification Report:
#
#                           precision    recall  f1-score   support
#
#                acid_base       1.00      0.43      0.60        60
#      activation_function       1.00      0.87      0.93        60
#           active_passive       1.00      1.00      1.00        60
#    ancient_civilizations       1.00      0.90      0.95        60
#              area_volume       1.00      1.00      1.00        60
#   arithmetic_progression       1.00      1.00      1.00        60
#  artificial_intelligence       0.91      1.00      0.95        60
#           atom_structure       0.55      1.00      0.71        60
#          backpropagation       0.93      0.90      0.92        60
#            binary_number       1.00      1.00      1.00        60
#          career_guidance       1.00      1.00      1.00        60
#             cell_biology       1.00      1.00      1.00        60
#         chemical_bonding       1.00      1.00      1.00        60
#        chemical_reaction       0.00      0.00      0.00        60
#       circulatory_system       0.00      0.00      0.00        60
#          climate_weather       0.97      0.93      0.95        60
#                      cnn       1.00      0.94      0.97        62
#                 cold_war       1.00      1.00      1.00        60
#        compound_interest       1.00      0.97      0.98        60
#            comprehension       1.00      0.97      0.98        60
#          computer_basics       1.00      0.03      0.06        60
#            concentration       0.97      1.00      0.98        60
#       constitution_india       1.00      0.93      0.97        60
#        continents_oceans       1.00      1.00      1.00        60
#                corrosion       0.00      0.00      0.00        60
#            cybersecurity       0.96      0.77      0.85        60
#          data_structures       1.00      1.00      1.00        60
# deep_learning_frameworks       1.00      0.13      0.24        60
#      deep_learning_intro       0.91      0.97      0.94        60
#                  default       1.00      1.00      1.00        60
#          differentiation       0.54      0.43      0.48        60
#         digestive_system       1.00      1.00      1.00        60
#          direct_indirect       1.00      1.00      1.00        60
#                  dropout       0.90      0.93      0.92        60
#                ecosystem       0.51      0.67      0.58        60
#              electricity       0.75      1.00      0.86        60
#             electrolysis       0.96      0.77      0.85        60
# electromagnetic_spectrum       1.00      0.87      0.93        60
#             epochs_batch       1.00      0.57      0.72        60
#      equations_of_motion       0.97      1.00      0.98        60
#            essay_writing       1.00      1.00      1.00        60
#                evolution       1.00      0.27      0.42        60
#         exam_preparation       1.00      1.00      1.00        60
#                exponents       1.00      0.93      0.97        60
#            factorization       1.00      1.00      1.00        58
#               food_chain       0.57      0.43      0.49        60
#         freedom_fighters       1.00      0.83      0.91        60
#        french_revolution       1.00      1.00      1.00        60
#       fundamental_rights       1.00      1.00      1.00        60
#                 genetics       0.85      0.37      0.51        60
#                  goodbye       0.95      1.00      0.98       120
#         gradient_descent       1.00      0.40      0.57        60
#                  gravity       0.56      0.90      0.69        60
#        greenhouse_effect       1.00      0.97      0.98        60
#                 greeting       1.00      1.00      1.00       120
#                  hcf_lcm       1.00      1.00      1.00        60
#                     help       0.19      1.00      0.32        60
#          india_geography       1.00      1.00      1.00        60
#      indian_independence       0.93      0.93      0.93        60
#                 internet       0.45      0.97      0.61        60
#       latitude_longitude       1.00      1.00      1.00        60
#              lens_mirror       1.00      1.00      1.00        60
#           letter_writing       1.00      1.00      1.00        60
#          linear_equation       1.00      1.00      1.00        60
#         literary_devices       1.00      0.20      0.33        60
#            loss_function       1.00      1.00      1.00        60
#                     lstm       0.96      0.73      0.83        60
#            maurya_empire       1.00      1.00      1.00        60
#              memory_tips       1.00      1.00      1.00        60
#         metals_nonmetals       0.00      0.00      0.00        60
#             mole_concept       0.44      0.93      0.60        60
#            mughal_empire       0.93      0.93      0.93        60
#        natural_disasters       1.00      0.83      0.91        60
#           nervous_system       0.93      0.83      0.88        60
#           neural_network       0.49      0.97      0.65        60
#             newtons_laws       1.00      1.00      1.00        60
#              note_taking       0.94      1.00      0.97        60
#         operating_system       0.00      0.00      0.00        60
#        organic_chemistry       1.00      1.00      1.00        60
#         parliament_india       1.00      1.00      1.00        60
#          parts_of_speech       0.94      0.97      0.95        60
#               percentage       0.97      0.93      0.95        60
#           periodic_table       1.00      1.00      1.00        60
#           photosynthesis       1.00      0.97      0.98        60
#            plant_kingdom       1.00      0.97      0.98        60
#                pollution       0.30      1.00      0.46        60
#                 pressure       1.00      1.00      1.00        60
#              probability       0.75      0.30      0.43        60
#       programming_basics       0.44      1.00      0.61        60
#               pythagoras       0.91      0.97      0.94        60
#       quadratic_equation       1.00      1.00      1.00        60
#    reflection_refraction       1.00      1.00      1.00        60
#         renewable_energy       0.97      0.97      0.97        60
#             reproduction       0.85      0.97      0.91        60
#              respiration       1.00      0.77      0.87        60
#                      rnn       0.59      0.43      0.50        60
#           sentence_types       1.00      1.00      1.00        60
#          simple_interest       0.41      1.00      0.58        60
#               soil_types       1.00      1.00      1.00        60
#                    sound       1.00      0.93      0.97        60
#      speed_distance_time       0.00      0.00      0.00        60
#               statistics       1.00      0.93      0.96        58
#                   tenses       0.97      1.00      0.98        60
#                   thanks       1.00      1.00      1.00       120
#          time_management       1.00      1.00      1.00        60
#              transformer       0.00      0.00      0.00        60
#          trig_identities       0.33      0.63      0.43        60
#             trigonometry       0.74      0.93      0.82        60
#               vocabulary       1.00      0.57      0.72        60
#              water_cycle       1.00      1.00      1.00        60
#              who_are_you       0.65      0.43      0.52        60
#        work_energy_power       1.00      1.00      1.00        60
#               world_wars       1.00      1.00      1.00        60
#
#                 accuracy                           0.83      6958
#                macro avg       0.85      0.82      0.81      6958
#             weighted avg       0.85      0.83      0.81      6958
#
#
# Confusion Matrix:
#
# [[26  0  0 ...  0  0  0]
#  [ 0 52  0 ...  0  0  0]
#  [ 0  0 60 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 26  0  0]
#  [ 0  0  0 ...  0 60  0]
#  [ 0  0  0 ...  0  0 60]]
# C:\Users\hussa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\hussa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\hussa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(hist.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# Loss
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# Predictions
# -------------------------------
y_pred = model.predict(np.array(train_x))
y_pred_classes = np.argmax(y_pred, axis=1)

y_true = np.argmax(np.array(train_y), axis=1)

# -------------------------------
# Accuracy
# -------------------------------
accuracy = accuracy_score(y_true, y_pred_classes)
print(f"\nModel Accuracy: {accuracy * 100:.2f}%")

# -------------------------------
# Classification Report
# (Precision, Recall, F1-score)
# -------------------------------
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred_classes, target_names=classes))

# -------------------------------
# Confusion Matrix
# -------------------------------
cm = confusion_matrix(y_true, y_pred_classes)
print("\nConfusion Matrix:\n")
print(cm)

# -------------------------------
# Plot Confusion Matrix
# -------------------------------
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.colorbar()
plt.show()

# -------------------------------
# Plot Accuracy & Loss (Learning Curve)
# -------------------------------
plt.figure()
plt.plot(hist.history['accuracy'])
plt.title("Model Accuracy over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

plt.figure()
plt.plot(hist.history['loss'])
plt.title("Model Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()
# Out:
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Model Accuracy: 82.81%
#
# Classification Report:
#
#                           precision    recall  f1-score   support
#
#                acid_base       1.00      0.43      0.60        60
#      activation_function       1.00      0.87      0.93        60
#           active_passive       1.00      1.00      1.00        60
#    ancient_civilizations       1.00      0.90      0.95        60
#              area_volume       1.00      1.00      1.00        60
#   arithmetic_progression       1.00      1.00      1.00        60
#  artificial_intelligence       0.91      1.00      0.95        60
#           atom_structure       0.55      1.00      0.71        60
#          backpropagation       0.93      0.90      0.92        60
#            binary_number       1.00      1.00      1.00        60
#          career_guidance       1.00      1.00      1.00        60
#             cell_biology       1.00      1.00      1.00        60
#         chemical_bonding       1.00      1.00      1.00        60
#        chemical_reaction       0.00      0.00      0.00        60
#       circulatory_system       0.00      0.00      0.00        60
#          climate_weather       0.97      0.93      0.95        60
#                      cnn       1.00      0.94      0.97        62
#                 cold_war       1.00      1.00      1.00        60
#        compound_interest       1.00      0.97      0.98        60
#            comprehension       1.00      0.97      0.98        60
#          computer_basics       1.00      0.03      0.06        60
#            concentration       0.97      1.00      0.98        60
#       constitution_india       1.00      0.93      0.97        60
#        continents_oceans       1.00      1.00      1.00        60
#                corrosion       0.00      0.00      0.00        60
#            cybersecurity       0.96      0.77      0.85        60
#          data_structures       1.00      1.00      1.00        60
# deep_learning_frameworks       1.00      0.13      0.24        60
#      deep_learning_intro       0.91      0.97      0.94        60
#                  default       1.00      1.00      1.00        60
#          differentiation       0.54      0.43      0.48        60
#         digestive_system       1.00      1.00      1.00        60
#          direct_indirect       1.00      1.00      1.00        60
#                  dropout       0.90      0.93      0.92        60
#                ecosystem       0.51      0.67      0.58        60
#              electricity       0.75      1.00      0.86        60
#             electrolysis       0.96      0.77      0.85        60
# electromagnetic_spectrum       1.00      0.87      0.93        60
#             epochs_batch       1.00      0.57      0.72        60
#      equations_of_motion       0.97      1.00      0.98        60
#            essay_writing       1.00      1.00      1.00        60
#                evolution       1.00      0.27      0.42        60
#         exam_preparation       1.00      1.00      1.00        60
#                exponents       1.00      0.93      0.97        60
#            factorization       1.00      1.00      1.00        58
#               food_chain       0.57      0.43      0.49        60
#         freedom_fighters       1.00      0.83      0.91        60
#        french_revolution       1.00      1.00      1.00        60
#       fundamental_rights       1.00      1.00      1.00        60
#                 genetics       0.85      0.37      0.51        60
#                  goodbye       0.95      1.00      0.98       120
#         gradient_descent       1.00      0.40      0.57        60
#                  gravity       0.56      0.90      0.69        60
#        greenhouse_effect       1.00      0.97      0.98        60
#                 greeting       1.00      1.00      1.00       120
#                  hcf_lcm       1.00      1.00      1.00        60
#                     help       0.19      1.00      0.32        60
#          india_geography       1.00      1.00      1.00        60
#      indian_independence       0.93      0.93      0.93        60
#                 internet       0.45      0.97      0.61        60
#       latitude_longitude       1.00      1.00      1.00        60
#              lens_mirror       1.00      1.00      1.00        60
#           letter_writing       1.00      1.00      1.00        60
#          linear_equation       1.00      1.00      1.00        60
#         literary_devices       1.00      0.20      0.33        60
#            loss_function       1.00      1.00      1.00        60
#                     lstm       0.96      0.73      0.83        60
#            maurya_empire       1.00      1.00      1.00        60
#              memory_tips       1.00      1.00      1.00        60
#         metals_nonmetals       0.00      0.00      0.00        60
#             mole_concept       0.44      0.93      0.60        60
#            mughal_empire       0.93      0.93      0.93        60
#        natural_disasters       1.00      0.83      0.91        60
#           nervous_system       0.93      0.83      0.88        60
#           neural_network       0.49      0.97      0.65        60
#             newtons_laws       1.00      1.00      1.00        60
#              note_taking       0.94      1.00      0.97        60
#         operating_system       0.00      0.00      0.00        60
#        organic_chemistry       1.00      1.00      1.00        60
#         parliament_india       1.00      1.00      1.00        60
#          parts_of_speech       0.94      0.97      0.95        60
#               percentage       0.97      0.93      0.95        60
#           periodic_table       1.00      1.00      1.00        60
#           photosynthesis       1.00      0.97      0.98        60
#            plant_kingdom       1.00      0.97      0.98        60
#                pollution       0.30      1.00      0.46        60
#                 pressure       1.00      1.00      1.00        60
#              probability       0.75      0.30      0.43        60
#       programming_basics       0.44      1.00      0.61        60
#               pythagoras       0.91      0.97      0.94        60
#       quadratic_equation       1.00      1.00      1.00        60
#    reflection_refraction       1.00      1.00      1.00        60
#         renewable_energy       0.97      0.97      0.97        60
#             reproduction       0.85      0.97      0.91        60
#              respiration       1.00      0.77      0.87        60
#                      rnn       0.59      0.43      0.50        60
#           sentence_types       1.00      1.00      1.00        60
#          simple_interest       0.41      1.00      0.58        60
#               soil_types       1.00      1.00      1.00        60
#                    sound       1.00      0.93      0.97        60
#      speed_distance_time       0.00      0.00      0.00        60
#               statistics       1.00      0.93      0.96        58
#                   tenses       0.97      1.00      0.98        60
#                   thanks       1.00      1.00      1.00       120
#          time_management       1.00      1.00      1.00        60
#              transformer       0.00      0.00      0.00        60
#          trig_identities       0.33      0.63      0.43        60
#             trigonometry       0.74      0.93      0.82        60
#               vocabulary       1.00      0.57      0.72        60
#              water_cycle       1.00      1.00      1.00        60
#              who_are_you       0.65      0.43      0.52        60
#        work_energy_power       1.00      1.00      1.00        60
#               world_wars       1.00      1.00      1.00        60
#
#                 accuracy                           0.83      6958
#                macro avg       0.85      0.82      0.81      6958
#             weighted avg       0.85      0.83      0.81      6958
#
#
# Confusion Matrix:
#
# [[26  0  0 ...  0  0  0]
#  [ 0 52  0 ...  0  0  0]
#  [ 0  0 60 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 26  0  0]
#  [ 0  0  0 ...  0 60  0]
#  [ 0  0  0 ...  0  0 60]]
# C:\Users\hussa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\hussa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\hussa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
